# %% [markdown]
# TASK-02:
# Perform data cleaning and exploratory data analysis (EDA) on a dataset of your choice, such as the Titanic dataset from Kaggle. Explore the relationships between variables and identify patterns and trends in the data.

# %%
#Importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Loading the dataset
data=pd.read_csv("P:/Prodigy internship/task2.csv")

# %%
#displaying the data
data
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 707          711         0       3  female  39.0      0      5  29.1250
# 708          712         0       2    male  27.0      0      0  13.0000
# 709          713         1       1  female  19.0      0      0  30.0000
# 710          714         1       1    male  26.0      0      0  30.0000
# 711          715         0       3    male  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# ...

# %%
#displaying first 4 rows
data.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0            1         0       3    male  22.0      1      0   7.2500        S
# 1            2         1       1  female  38.0      1      0  71.2833        C
# 2            3         1       3  female  26.0      0      0   7.9250        S
# 3            4         1       1  female  35.0      1      0  53.1000        S
# 4            5         0       3    male  35.0      0      0   8.0500        S

# %%
#displaying last 4 rows
data.tail()
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch    Fare  \
# 708          711         0       3  female  39.0      0      5  29.125
# 709          712         0       2    male  27.0      0      0  13.000
# 710          713         1       1  female  19.0      0      0  30.000
# 711          714         1       1    male  26.0      0      0  30.000
# 712          715         0       3    male  32.0      0      0   7.750
#
#     Embarked
# 708        Q
# 709        S
# 710        S
# 711        C
# 712        Q

# %%
data.describe()
# Out:
#        PassengerId   Survived      Pclass         Age       SibSp       Parch  \
# count   713.000000  713.00000  713.000000  712.000000  713.000000  713.000000
# mean    358.007013    0.40533    2.241234   29.642093    0.513324    0.431978
# std     206.189591    0.49130    0.836750   14.492933    0.930238    0.853735
# min       1.000000    0.00000    1.000000    0.420000    0.000000    0.000000
# 25%     180.000000    0.00000    1.000000   20.000000    0.000000    0.000000
# 50%     358.000000    0.00000    2.000000   28.000000    0.000000    0.000000
# 75%     536.000000    1.00000    3.000000   38.000000    1.000000    1.000000
# max     715.000000    1.00000    3.000000   80.000000    5.000000    6.000000
#
#              Fare
# count  713.000000
# mean    34.529821
# std     52.910900
# min      0.000000
# 25%      8.050000
# 50%     15.550000
# 75%     33.000000
# max    512.329200

# %%
data.shape
# Out:
# (713, 9)

# %%
#displaying the columns
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Fare', 'Embarked'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 713 entries, 0 to 712
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  713 non-null    int64
#  1   Survived     713 non-null    int64
#  2   Pclass       713 non-null    int64
#  3   Sex          713 non-null    object
#  4   Age          712 non-null    float64
#  5   SibSp        713 non-null    int64
#  6   Parch        713 non-null    int64
#  7   Fare         713 non-null    float64
#  8   Embarked     713 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 50.3+ KB

# %%
data.sample(5)
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch      Fare  \
# 485          486         0       3  female   NaN      3      1   25.4667
# 159          160         0       3    male   NaN      8      2   69.5500
# 796          797         1       1  female  49.0      0      0   25.9292
# 721          722         0       3    male  17.0      1      0    7.0542
# 660          661         1       1    male  50.0      2      0  133.6500
#
#     Embarked
# 485        S
# 159        S
# 796        S
# 721        S
# 660        S

# %%
#checking missing values
print(data.isnull().sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %%
datadict=pd.DataFrame(data.dtypes)
datadict
# Out:
#                    0
# PassengerId    int64
# Survived       int64
# Pclass         int64
# Sex           object
# Age          float64
# SibSp          int64
# Parch          int64
# Fare         float64
# Embarked      object

# %%
datadict['MissingVal']=data.isnull().sum()
datadict
# Out:
#                    0  MissingVal
# PassengerId    int64           0
# Survived       int64           0
# Pclass         int64           0
# Sex           object           0
# Age          float64           0
# SibSp          int64           0
# Parch          int64           0
# Fare         float64           0
# Embarked      object           0

# %%
#Identify number of unique values,For object nunique will the number of levels
#Add the stats the data dict
datadict['NUnique']=data.nunique()
datadict
# Out:
#                    0  MissingVal  NUnique
# PassengerId    int64           0      712
# Survived       int64           0        2
# Pclass         int64           0        3
# Sex           object           0        2
# Age          float64           0       88
# SibSp          int64           0        6
# Parch          int64           0        7
# Fare         float64           0      219
# Embarked      object           0        3

# %%
#Identify the count for each variable,add the stats to dataset
datadict['Count']=data.count()
datadict
# Out:
#                    0  MissingVal  NUnique  Count
# PassengerId    int64           0      712    712
# Survived       int64           0        2    712
# Pclass         int64           0        3    712
# Sex           object           0        2    712
# Age          float64           0       88    712
# SibSp          int64           0        6    712
# Parch          int64           0        7    712
# Fare         float64           0      219    712
# Embarked      object           0        3    712

# %%
#rename the 0 column
datadict=datadict.rename(columns={0:'DataType'})
datadict
# Out:
#             DataType  MissingVal  NUnique  Count
# PassengerId    int64           0      712    712
# Survived       int64           0        2    712
# Pclass         int64           0        3    712
# Sex           object           0        2    712
# Age          float64           0       88    712
# SibSp          int64           0        6    712
# Parch          int64           0        7    712
# Fare         float64           0      219    712
# Embarked      object           0        3    712

# %%
#countplot to display survival based on sex
sns.countplot(x='Sex',hue='Survived',data=data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[64], line 2
#       1 #countplot to display survival based on sex
# ----> 2 sns.countplot(x='Sex',hue='Survived',data=data)
#       3 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:767, in _CategoricalPlotter.annotate_axes(self, ax)
# ...

# %%
#analyze passenger survival by pclass
sns.displot(data[data['Survived']==1]['Pclass'],label='Survived')
plt.legend()
plt.show()
# Out:
# C:\Users\vince\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#analyze passenger deceased by pclass
sns.displot(data[data['Survived']==0]['Pclass'],label='Deceased')
plt.show()
# Out:
# C:\Users\vince\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#finding the number of passengers survived and deceased
titanic_survived=data[data["Survived"]==1]
titanic_nonsurvived=data[data["Survived"]==0]
print(data.groupby("Survived")["PassengerId"].count())
# Out:
# Survived
# 0    424
# 1    288
# Name: PassengerId, dtype: int64

# %%
#finding the percentage of passengers survived and deceased
data.Survived.value_counts(normalize=True)
# Out:
# Survived
# 0    0.595506
# 1    0.404494
# Name: proportion, dtype: float64

# %% [markdown]
# NOTE:40% OF THE PASSENGERS SURVIVED,
#      60% OF THE PASSENGERS ARE NOT SURVIVED

# %%
fig=plt.figure(figsize=(5,5))
sns.countplot(x='Survived',data=data)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
fig=plt.figure(figsize=(5,5))
sns.countplot(x='Pclass',data=data)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
fig=plt.figure(figsize=(5,5))
sns.countplot(x='Sex',data=data)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
fig=plt.figure(figsize=(5,5))
sns.countplot(x='SibSp',data=data)
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
fig=plt.figure(figsize=(5,5))
sns.countplot(x='Parch',data=data)
# Out:
# <Axes: xlabel='Parch', ylabel='count'>

# %%
fig=plt.figure(figsize=(5,5))
sns.countplot(x='Embarked',data=data)
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
sns.displot(data['Age'],kde=True)
# Out:
# C:\Users\vince\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#the distribution of ages of the passengers
plt.figure(figsize=(10,6))
sns.histplot(data=data,x='Age',kde=True,hue='Sex')
plt.title('Age distribution by Gender')
plt.show()
# Out:
# C:\Users\vince\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# EXPLORATORY DATA ANALYSIS(EDA)

# %%
def dist_box(data):
    Name=data.name.upper()
    fig,(ax_box,ax_dis)=plt.subplots(nrows=2,sharex=True,gridspec_kw={"height_ratios":(.25, .75)},figsize=(8, 5))
    mean=data.mean()
    median=data.median()
    mode=data.mode().tolist()[0]
    sns.set_theme(style="white")
    sns.set_palette(sns.color_palette("Set1",8))
    fig.suptitle("SPREAD OF DATA FOR"+Name,fontsize=18,fontweight='bold')
    sns.boxplot(x=data,showmeans=True,orient='h',ax=ax_box)
    ax_box.set(xlabel='')
    sns.despine(top=True,right=True,left=True)
    sns.set_palette(sns.color_palette("Set1",8))
    sns.distplot(data,kde=False,ax=ax_dis)
    ax_dis.axvline(mean,color='r',linestyle='--',linewidth=2)
    ax_dis.axvline(median,color='g',linestyle='--',linewidth=2)
    ax_dis.axvline(mode,color='y',linestyle='--',linewidth=2)
    plt.legend({'Mean':mean,'Median':median,'Mode':mode})

# %%
#select all quantitative columns for checking the spread
list_col=data.select_dtypes(include='number').columns.to_list()
for i in range(len(list_col)):
    dist_box(data[list_col[i]])
# Out:
# C:\Users\vince\AppData\Local\Temp\ipykernel_22496\3729237436.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data,kde=False,ax=ax_dis)
# C:\Users\vince\AppData\Local\Temp\ipykernel_22496\3729237436.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
# The distribution of the outcome variable in the data was examined and visualized.
f,ax=plt.subplots(1,2,figsize=(18,8))
custom_palette = ['#00FF7F', '#FFD700']
data['Survived'].value_counts().plot.pie(explode=[0,0.1],colors=custom_palette,autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('target')
ax[0].set_ylabel('')

# Define custom colors
custom_palette = ['#E6E6FA', '#D3D3D3']

sns.countplot(x='Survived',data=data,palette=custom_palette,ax=ax[1])
ax[1].set_title('Outcome')
plt.show()
